# %%
'''
Function Description:对图片进行拉伸、旋转、裁剪、缩放等操作增加数据量，然后进行训练
'''
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
import os
import matplotlib.pyplot as plt 
import numpy as np 
#加载图片，并对图片进行相应操作
base_dir = '/home/liangyi/workplace/python/MachineLearning/NeuralNetwork/cat-and-dog/'
train_cat_dir = os.path.join(base_dir, 'training_set/cats')
train_dog_dir = os.path.join(base_dir, 'training_set/dogs')
test_cat_dir = os.path.join(base_dir, 'test_set/cats')
test_dog_dir = os.path.join(base_dir, 'test_set/dogs')

# %%
#对图片进行操作
datagen = ImageDataGenerator(rotation_range=40, width_shift_range=0.2, 
                             height_shift_range=0.2, #注意换行这个地方千万不能加空格
                             shear_range=0.2, zoom_range=0.2, horizontal_flip=True, fill_mode='nearest')
fnames = [os.path.join(train_dog_dir, fname) for fname in os.listdir(train_dog_dir)]
img_path = fnames[1]
#img_path = train_dog_dir[1]
print(img_path)


img = image.load_img(img_path, target_size=(150,150))
img = image.img_to_array(img)
#对图片做6种变换
img = img.reshape((1,) + img.shape)
i = 0
f, ax = plt.subplots(1, 6)
for batch in datagen.flow(img, batch_size=1):
    imgplot = ax[i].imshow(image.array_to_img(batch[0]))
    ax[i].axis('off')
    i += 1
    if i % 6 == 0:
        break
plt.show()
# Out:
# /home/liangyi/workplace/python/MachineLearning/NeuralNetwork/cat-and-dog/training_set/dogs/dog.2893.jpg

# %%
#设置CNN，（150，150，3），32，64，128，128，512，1
from keras import layers
from keras import models
model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), activation = 'relu', input_shape = (150,150,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(128, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(128, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dense(512, activation = 'relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer = 'rmsprop', metrics = ['acc'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 6272)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               3211776
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import preprocessing
#将图片加载到内存中
path_cats = []
for path in os.listdir(train_cat_dir):
    if '.jpg' in path:
        path_cats.append(os.path.join(train_cat_dir, path))
path_dogs = []
for path in os.listdir(train_dog_dir):
    if '.jpg' in path:
        path_dogs.append(os.path.join(train_dog_dir, path))

#将training图片转换为（150，150）的二维数组.猫3000张，狗3000张
training_set = np.zeros((6000,150,150,3), dtype='float32')
train_dog_imgs = 3000
train_cat_imgs = 3000
for i in range(train_dog_imgs):
    img = preprocessing.image.load_img(path_dogs[i], target_size = (150,150))
    training_set[i] = preprocessing.image.img_to_array(img)
for j in range(train_cat_imgs):
    img = preprocessing.image.load_img(path_cats[j], target_size = (150,150))
    training_set[j+train_dog_imgs] = preprocessing.image.img_to_array(img)
#准备2000张图片作为val_set,猫狗各1000张
val_set = np.zeros((2000,150,150,3), dtype='float32')
val_dog_imgs = 1000
val_cat_imgs = 1000
for i in range(val_dog_imgs):
    path = path_dogs[i+train_dog_imgs]
    img = preprocessing.image.load_img(path, target_size = (150,150))
    val_set[i] = preprocessing.image.img_to_array(img)
for j in range(val_cat_imgs):
    path = path_cats[j+train_cat_imgs]
    img = preprocessing.image.load_img(path, target_size = (150,150))
    val_set[j+val_cat_imgs] = preprocessing.image.img_to_array(img)

#设置猫狗图片的标签，狗为1，猫为0
train_labels = np.zeros((3000, ))
train_labels = np.concatenate((train_labels, np.ones(3000, )))
val_labels = np.zeros((1000,))
val_labels = np.concatenate((val_labels, np.ones(1000, )))

# %%
#将图片的像素转换到[0,1]之间
train_datagen = ImageDataGenerator(rescale=1./255, rotation_range=40, width_shift_range=0.2, 
                             height_shift_range=0.2, #注意换行这个地方千万不能加空格
                             shear_range=0.2, zoom_range=0.2, horizontal_flip=True)
train_generator = train_datagen.flow(training_set, train_labels, batch_size = 32)
val_datagen = ImageDataGenerator(rescale=1./255)
val_generator = val_datagen.flow(val_set, val_labels, batch_size = 32)

# %%
history = model.fit(train_generator, steps_per_epoch=100, epochs=30, validation_data=val_generator, validation_steps=50)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 52s 509ms/step - loss: 0.7833 - acc: 0.4933 - val_loss: 0.6912 - val_acc: 0.5006
# Epoch 2/30
# 100/100 [==============================] - 54s 539ms/step - loss: 0.6893 - acc: 0.5521 - val_loss: 0.7500 - val_acc: 0.5612
# Epoch 3/30
# 100/100 [==============================] - 52s 521ms/step - loss: 0.6673 - acc: 0.5920 - val_loss: 0.6558 - val_acc: 0.5644
# Epoch 4/30
# 100/100 [==============================] - 49s 494ms/step - loss: 0.6708 - acc: 0.5960 - val_loss: 0.6286 - val_acc: 0.6494
# Epoch 5/30
# 100/100 [==============================] - 51s 504ms/step - loss: 0.6590 - acc: 0.5957 - val_loss: 0.6864 - val_acc: 0.5600
# Epoch 6/30
# 100/100 [==============================] - 49s 492ms/step - loss: 0.6420 - acc: 0.6249 - val_loss: 0.6105 - val_acc: 0.6837
# Epoch 7/30
# 100/100 [==============================] - 52s 515ms/step - loss: 0.6238 - acc: 0.6541 - val_loss: 0.6164 - val_acc: 0.6313
# Epoch 8/30
# 100/100 [==============================] - 51s 512ms/step - loss: 0.6002 - acc: 0.6812 - val_loss: 0.5928 - val_acc: 0.6900
# Epoch 9/30
# 100/100 [==============================] - 46s 453ms/step - loss: 0.6124 - acc: 0.6816 - val_loss: 0.5390 - val_acc: 0.7225
# Epoch 10/30
# 100/100 [==============================] - 45s 451ms/step - loss: 0.6101 - acc: 0.6869 - val_loss: 0.5618 - val_acc: 0.7300
# Epoch 11/30
# 100/100 [==============================] - 45s 445ms/step - loss: 0.5884 - acc: 0.6870 - val_loss: 0.5434 - val_acc: 0.7294
# Epoch 12/30
# 100/100 [==============================] - 43s 431ms/step - loss: 0.5932 - acc: 0.6955 - val_loss: 0.5342 - val_acc: 0.7269
# Epoch 13/30
# 100/100 [==============================] - 45s 448ms/step - loss: 0.5606 - acc: 0.7076 - val_loss: 0.5394 - val_acc: 0.7200
# Epoch 14/30
# 100/100 [==============================] - 44s 437ms/step - loss: 0.5751 - acc: 0.7049 - val_loss: 0.5620 - val_acc: 0.7306
# Epoch 15/30
# 100/100 [==============================] - 45s 446ms/step - loss: 0.5638 - acc: 0.7052 - val_loss: 0.5765 - val_acc: 0.7013
# Epoch 16/30
# 100/100 [==============================] - 44s 438ms/step - loss: 0.5350 - acc: 0.7370 - val_loss: 0.5054 - val_acc: 0.7644
# Epoch 17/30
# 100/100 [==============================] - 44s 438ms/step - loss: 0.5535 - acc: 0.7146 - val_loss: 0.4804 - val_acc: 0.7788
# Epoch 18/30
# 100/100 [==============================] - 47s 465ms/step - loss: 0.5294 - acc: 0.7285 - val_loss: 0.4839 - val_acc: 0.7756
# Epoch 19/30
# 100/100 [==============================] - 54s 538ms/step - loss: 0.5294 - acc: 0.7318 - val_loss: 0.4636 - val_acc: 0.7937
# Epoch 20/30
# 100/100 [==============================] - 46s 456ms/step - loss: 0.5536 - acc: 0.7286 - val_loss: 0.4775 - val_acc: 0.7981
# Epoch 21/30
# 100/100 [==============================] - 50s 496ms/step - loss: 0.5418 - acc: 0.7320 - val_loss: 0.5751 - val_acc: 0.7419
# Epoch 22/30
# 100/100 [==============================] - 51s 507ms/step - loss: 0.5298 - acc: 0.7456 - val_loss: 0.4571 - val_acc: 0.7862
# Epoch 23/30
# 100/100 [==============================] - 47s 469ms/step - loss: 0.5370 - acc: 0.7391 - val_loss: 0.4941 - val_acc: 0.7500
# Epoch 24/30
# 100/100 [==============================] - 50s 495ms/step - loss: 0.4998 - acc: 0.7454 - val_loss: 0.6102 - val_acc: 0.7206
# Epoch 25/30
# 100/100 [==============================] - 51s 506ms/step - loss: 0.5131 - acc: 0.7554 - val_loss: 0.4909 - val_acc: 0.7725
# Epoch 26/30
# 100/100 [==============================] - 46s 460ms/step - loss: 0.5257 - acc: 0.7552 - val_loss: 0.5044 - val_acc: 0.7744
# Epoch 27/30
# 100/100 [==============================] - 47s 473ms/step - loss: 0.5032 - acc: 0.7654 - val_loss: 0.4696 - val_acc: 0.7669
# Epoch 28/30
# 100/100 [==============================] - 47s 474ms/step - loss: 0.4969 - acc: 0.7659 - val_loss: 0.4470 - val_acc: 0.8031
# Epoch 29/30
# 100/100 [==============================] - 48s 479ms/step - loss: 0.4832 - acc: 0.7762 - val_loss: 0.4750 - val_acc: 0.7881
# Epoch 30/30
# 100/100 [==============================] - 46s 457ms/step - loss: 0.4697 - acc: 0.7877 - val_loss: 0.6393 - val_acc: 0.7013

# %%
#展示acc和loss
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, 1 + len(acc))
plt.plot(epochs, acc, 'b', label = 'acc')
plt.plot(epochs, val_acc, 'bo', label = 'val_acc')
plt.title('acc')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label = 'loss')
plt.plot(epochs, val_loss, 'bo', label = 'val_loss')
plt.title('acc')
plt.legend()

plt.show()

# %%
#在原来的网络上增加一层Dropout
model = models.Sequential()
model.add(layers.Conv2D(32, (3,3), activation = 'relu', input_shape = (150,150,3)))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(64, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(128, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Conv2D(128, (3,3), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Flatten())
model.add(layers.Dropout(0.5))#0.5的意思是把一半的参数清零
model.add(layers.Dense(512, activation = 'relu'))
model.add(layers.Dense(1, activation='sigmoid'))
model.compile(loss = 'binary_crossentropy', optimizer = 'rmsprop', metrics = ['acc'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 34, 34, 128)       73856
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 17, 17, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 15, 15, 128)       147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 7, 7, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 6272)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               3211776
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 3,453,121
# Trainable params: 3,453,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_generator, steps_per_epoch=100, epochs=30, validation_data=val_generator, validation_steps=50)
# Out:
# Epoch 1/30
# 100/100 [==============================] - 51s 505ms/step - loss: 0.8507 - acc: 0.5172 - val_loss: 0.6768 - val_acc: 0.5469
# Epoch 2/30
# 100/100 [==============================] - 50s 503ms/step - loss: 0.6953 - acc: 0.5609 - val_loss: 0.6566 - val_acc: 0.5994
# Epoch 3/30
# 100/100 [==============================] - 52s 515ms/step - loss: 0.6810 - acc: 0.5808 - val_loss: 0.6510 - val_acc: 0.5800
# Epoch 4/30
# 100/100 [==============================] - 51s 507ms/step - loss: 0.6683 - acc: 0.5873 - val_loss: 0.6340 - val_acc: 0.6544
# Epoch 5/30
# 100/100 [==============================] - 51s 505ms/step - loss: 0.6459 - acc: 0.6282 - val_loss: 0.6133 - val_acc: 0.6831
# Epoch 6/30
# 100/100 [==============================] - 51s 505ms/step - loss: 0.6405 - acc: 0.6263 - val_loss: 0.6076 - val_acc: 0.6737
# Epoch 7/30
# 100/100 [==============================] - 45s 445ms/step - loss: 0.6374 - acc: 0.6476 - val_loss: 0.6045 - val_acc: 0.6681
# Epoch 8/30
# 100/100 [==============================] - 44s 441ms/step - loss: 0.6259 - acc: 0.6585 - val_loss: 0.6013 - val_acc: 0.6675
# Epoch 9/30
# 100/100 [==============================] - 43s 434ms/step - loss: 0.6103 - acc: 0.6668 - val_loss: 0.8809 - val_acc: 0.5950
# Epoch 10/30
# 100/100 [==============================] - 44s 441ms/step - loss: 0.6283 - acc: 0.6632 - val_loss: 0.5540 - val_acc: 0.7163
# Epoch 11/30
# 100/100 [==============================] - 42s 419ms/step - loss: 0.6305 - acc: 0.6532 - val_loss: 0.5555 - val_acc: 0.7075
# Epoch 12/30
# 100/100 [==============================] - 43s 429ms/step - loss: 0.6139 - acc: 0.6666 - val_loss: 0.6771 - val_acc: 0.6369
# Epoch 13/30
# 100/100 [==============================] - 44s 441ms/step - loss: 0.5854 - acc: 0.6866 - val_loss: 0.5196 - val_acc: 0.7531
# Epoch 14/30
# 100/100 [==============================] - 44s 440ms/step - loss: 0.6054 - acc: 0.6820 - val_loss: 0.5298 - val_acc: 0.7525
# Epoch 15/30
# 100/100 [==============================] - 44s 441ms/step - loss: 0.5727 - acc: 0.7009 - val_loss: 0.5131 - val_acc: 0.7738
# Epoch 16/30
# 100/100 [==============================] - 45s 453ms/step - loss: 0.5548 - acc: 0.7244 - val_loss: 0.5845 - val_acc: 0.7113
# Epoch 17/30
# 100/100 [==============================] - 43s 425ms/step - loss: 0.5580 - acc: 0.7269 - val_loss: 0.5427 - val_acc: 0.7244
# Epoch 18/30
# 100/100 [==============================] - 43s 431ms/step - loss: 0.5670 - acc: 0.7160 - val_loss: 0.4935 - val_acc: 0.7725
# Epoch 19/30
# 100/100 [==============================] - 44s 435ms/step - loss: 0.5385 - acc: 0.7211 - val_loss: 0.4813 - val_acc: 0.7925
# Epoch 20/30
# 100/100 [==============================] - 45s 445ms/step - loss: 0.5719 - acc: 0.7192 - val_loss: 0.5391 - val_acc: 0.7294
# Epoch 21/30
# 100/100 [==============================] - 44s 439ms/step - loss: 0.5471 - acc: 0.7333 - val_loss: 0.7239 - val_acc: 0.7081
# Epoch 22/30
# 100/100 [==============================] - 43s 431ms/step - loss: 0.5383 - acc: 0.7212 - val_loss: 0.5153 - val_acc: 0.7600
# Epoch 23/30
# 100/100 [==============================] - 43s 426ms/step - loss: 0.5101 - acc: 0.7534 - val_loss: 0.4775 - val_acc: 0.8075
# Epoch 24/30
# 100/100 [==============================] - 45s 446ms/step - loss: 0.5434 - acc: 0.7464 - val_loss: 0.4809 - val_acc: 0.7613
# Epoch 25/30
# 100/100 [==============================] - 44s 439ms/step - loss: 0.5036 - acc: 0.7717 - val_loss: 0.4838 - val_acc: 0.7694
# Epoch 26/30
# 100/100 [==============================] - 43s 434ms/step - loss: 0.5285 - acc: 0.7508 - val_loss: 0.4900 - val_acc: 0.7781
# Epoch 27/30
# 100/100 [==============================] - 44s 440ms/step - loss: 0.5157 - acc: 0.7535 - val_loss: 0.4525 - val_acc: 0.8037
# Epoch 28/30
# 100/100 [==============================] - 44s 438ms/step - loss: 0.5310 - acc: 0.7435 - val_loss: 0.4286 - val_acc: 0.8075
# Epoch 29/30
# 100/100 [==============================] - 43s 429ms/step - loss: 0.5028 - acc: 0.7710 - val_loss: 0.4872 - val_acc: 0.7694
# Epoch 30/30
# 100/100 [==============================] - 46s 454ms/step - loss: 0.6875 - acc: 0.7371 - val_loss: 0.4508 - val_acc: 0.7881

# %%
#展示acc和loss
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, 1 + len(acc))
plt.plot(epochs, acc, 'b', label = 'acc')
plt.plot(epochs, val_acc, 'bo', label = 'val_acc')
plt.title('acc')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'b', label = 'loss')
plt.plot(epochs, val_loss, 'bo', label = 'val_loss')
plt.title('acc')
plt.legend()

plt.show()
